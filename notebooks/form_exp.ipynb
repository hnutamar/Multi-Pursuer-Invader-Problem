# %% [markdown]
# # Experiments with formation

# %% [markdown]
# Firstly, we need to add project path to system.

# %%
import sys
import os
proj_path = '../src/'
path_to_proj = os.path.abspath(proj_path)
if path_to_proj not in sys.path:
    sys.path.append(path_to_proj)

# %%
import sim2D
import sim_config2D
import simulator
from sim_config2D import Sim2DConfig
from simulator import DroneSimulation
import importlib
importlib.reload(sim2D)
importlib.reload(sim_config2D)
importlib.reload(simulator)
# Out:
# <module 'simulator' from '/mnt/c/Users/Marek Hnuta/Desktop/FEL/5._Semestr/PROJ/multiple-pursuer-invader-problem/src/simulator.py'>

# %%
import numpy as np

# %% [markdown]
# First experiment is done with 6 pursuers. The maximum acceleration of pursuers will be 1.0, acceleration of Prime unit is only 0.1, which in current settings makes pursuers 3 times faster than Prime. That is why pursuers should not have a problem with keeping the formation intact.

# %%
PURSUER_NUM = 6
INVADER_NUM = 0
PURS_ACC = 1.0
PRIME_ACC = 0.1
prime_pos = np.array([3.0, 3.0])
purs_pos = np.array([[5.0, 5.0], [0.0, 0.0], [5.0, 0.0], [2.0, 5.0], [3.0, 5.0], [0.0, 3.0]])
#crash enabled from the beginning
CRASH_ENABLED = 1

conf = Sim2DConfig(purs_num=PURSUER_NUM, inv_num=INVADER_NUM, world_height=30, world_width=30)
sim = DroneSimulation(conf, purs_acc=PURS_ACC, prime_acc=PRIME_ACC, 
                    prime_pos=prime_pos, purs_pos=purs_pos, crash_enabled=CRASH_ENABLED)
sim.run()
# Out:
# crash enabled!

# %% [markdown]
# When we increase number of pursuers to for example 20, pursuers start to have problem with avoid all the other pursuers before settling to the formation. This is caused slightly by the random positional initialization. That can lead to pursuers flying too fast to formation, but because of the strong repulsive force inside of the formation, they are immediately being thrown outside, where other pursuers are. Once pursuers settle in their position, probability of collision is much lower.

# %%
PURSUER_NUM = 20
INVADER_NUM = 0
PURS_ACC = 1.0
PRIME_ACC = 0.1
prime_pos = np.array([3.0, 3.0])
purs_pos = np.array([[7.0, 7.0], [-2.0, -2.0], [7.0, -2.0], [-2.0, 7.0], [7.0, 4.0], [7.0, 1.0], [-2.0, 1.0], [-2.0, 4.0], 
                     [1.0, 7.0], [4.0, 7.0], [1.0, -2.0], [4.0, -2.0], [5.0, 5.0], [0.0, 0.0], [5.0, 0.0], [2.0, 5.0], 
                     [3.0, 5.0], [0.0, 3.0], [9.0, 9.0], [9.0, 0.0]])
#crash enabled from the beginning
CRASH_ENABLED = 1

conf = Sim2DConfig(purs_num=PURSUER_NUM, inv_num=INVADER_NUM, world_height=30, world_width=30)
sim = DroneSimulation(conf, purs_acc=PURS_ACC, prime_acc=PRIME_ACC, 
                    prime_pos=prime_pos, purs_pos=purs_pos, crash_enabled=CRASH_ENABLED)
sim.run()
# Out:
# crash enabled!

# %% [markdown]
# Now, what if Prime unit flies faster? This can definitely pose a problem for pursuers, whose algorithm, by now, rely only on vortex field, which forces them to circle around the Prime. This could be solved by not letting Prime fly faster than some fixed speed or by adding another formation alogrithm for pursuers, which would be used as needed.

# %%
PURSUER_NUM = 6
INVADER_NUM = 0
PURS_ACC = 1.0
PRIME_ACC = 0.3
prime_pos = np.array([3.0, 3.0])
purs_pos = np.array([[5.0, 5.0], [0.0, 0.0], [5.0, 0.0], [2.0, 5.0], [3.0, 5.0], [0.0, 3.0]])
#crash enabled from the beginning
CRASH_ENABLED = 1

conf = Sim2DConfig(purs_num=PURSUER_NUM, inv_num=INVADER_NUM, world_height=30, world_width=30)
sim = DroneSimulation(conf, purs_acc=PURS_ACC, prime_acc=PRIME_ACC, 
                    prime_pos=prime_pos, purs_pos=purs_pos, crash_enabled=CRASH_ENABLED)
sim.run()
# Out:
# crash enabled!
