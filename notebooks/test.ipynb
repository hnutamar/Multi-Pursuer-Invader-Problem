# %%
a = 1
print(a)
# Out:
# Running cells with 'venv (Python 3.12.3)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"/mnt/c/Users/Marek Hnuta/Desktop/FEL/5._Semestr/PROJ/multiple-pursuer-invader-problem/venv/bin/python" -m pip install ipykernel -U --force-reinstall'
